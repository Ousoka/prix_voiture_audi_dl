# %% [markdown]
# <a href="https://www.kaggle.com/code/ousoka/prix-voiture-audi-dl?scriptVersionId=232297048" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('/kaggle/input/prix-voiture-audi-dataset/prix_voiture_audi.xls')

# Display the first few rows
df.head()
# Out:
#   model  annee   prix transmission  miles carburant  taxe  distance  moteur
# 0    A1   2017  12500       Manual  15735    Petrol   150      55.4     1.4
# 1    A6   2016  16500    Automatic  36203    Diesel    20      64.2     2.0
# 2    A1   2016  11000       Manual  29946    Petrol    30      55.4     1.4
# 3    A4   2017  16800    Automatic  25952    Diesel   145      67.3     2.0
# 4    A3   2019  17300       Manual   1998    Petrol   145      49.6     1.0
